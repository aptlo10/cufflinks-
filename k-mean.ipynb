# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('c:/data/Mall_Customers.csv')

# %%
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# CustomerID                200 non-null int64
# Genre                     200 non-null object
# Age                       200 non-null int64
# Annual Income (k$)        200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
X = dataset.iloc[:, [3, 4]].values

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',max_iter=300,n_init=10,random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++',max_iter=300,n_init=10,random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %%
type(y_kmeans)
# Out:
# numpy.ndarray

# %%
new_kmean=y_kmeans.tolist()

# %%
type(new_kmean)
# Out:
# list

# %%
df = pd.DataFrame({'col':new_kmean})

# %%
df.head()
# Out:
#    col
# 0    4
# 1    3
# 2    4
# 3    3
# 4    4

# %%
final=pd.concat([df,dataset],axis=1)

# %%
final.head(200)
# Out:
#      col  CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      4           1    Male   19                  15                      39
# 1      3           2    Male   21                  15                      81
# 2      4           3  Female   20                  16                       6
# 3      3           4  Female   23                  16                      77
# 4      4           5  Female   31                  17                      40
# 5      3           6  Female   22                  17                      76
# 6      4           7  Female   35                  18                       6
# 7      3           8  Female   23                  18                      94
# 8      4           9    Male   64                  19                       3
# 9      3          10  Female   30                  19                      72
# 10     4          11    Male   67                  19                      14
# 11     3          12  Female   35                  19                      99
# 12     4          13  Female   58                  20                      15
# 13     3          14  Female   24                  20                      77
# 14     4          15    Male   37                  20                      13
# 15     3          16    Male   22                  20                      79
# 16     4          17  Female   35                  21                      35
# 17     3          18    Male   20                  21                      66
# 18     4          19    Male   52                  23                      29
# 19     3          20  Female   35                  23                      98
# 20     4          21    Male   35                  24                      35
# 21     3          22    Male   25                  24                      73
# 22     4          23  Female   46                  25                       5
# 23     3          24    Male   31                  25                      73
# 24     4          25  Female   54                  28                      14
# 25     3          26    Male   29                  28                      82
# 26     4          27  Female   45                  28                      32
# 27     3          28    Male   35                  28                      61
# 28     4          29  Female   40                  29                      31
# 29     3          30  Female   23                  29                      87
# ..   ...         ...     ...  ...                 ...                     ...
# 170    0         171    Male   40                  87                      13
# 171    2         172    Male   28                  87                      75
# 172    0         173    Male   36                  87                      10
# 173    2         174    Male   36                  87                      92
# 174    0         175  Female   52                  88                      13
# 175    2         176  Female   30                  88                      86
# 176    0         177    Male   58                  88                      15
# 177    2         178    Male   27                  88                      69
# 178    0         179    Male   59                  93                      14
# 179    2         180    Male   35                  93                      90
# 180    0         181  Female   37                  97                      32
# 181    2         182  Female   32                  97                      86
# 182    0         183    Male   46                  98                      15
# 183    2         184  Female   29                  98                      88
# 184    0         185  Female   41                  99                      39
# 185    2         186    Male   30                  99                      97
# 186    0         187  Female   54                 101                      24
# 187    2         188    Male   28                 101                      68
# 188    0         189  Female   41                 103                      17
# 189    2         190  Female   36                 103                      85
# 190    0         191  Female   34                 103                      23
# 191    2         192  Female   32                 103                      69
# 192    0         193    Male   33                 113                       8
# 193    2         194  Female   38                 113                      91
# 194    0         195  Female   47                 120                      16
# 195    2         196  Female   35                 120                      79
# 196    0         197  Female   45                 126                      28
# 197    2         198    Male   32                 126                      74
# 198    0         199    Male   32                 137                      18
# 199    2         200    Male   30                 137                      83
#
# [200 rows x 6 columns]

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
# col                       200 non-null int64
# CustomerID                200 non-null int64
# Genre                     200 non-null object
# Age                       200 non-null int64
# Annual Income (k$)        200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 9.4+ KB
